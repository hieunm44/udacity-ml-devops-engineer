# %% [markdown]
# ## Fetch the artifact created (sample.csv) from W&B and read it with pandas

# %%
 import wandb
 import pandas as pd

 run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
 local_path = wandb.use_artifact("sample.csv:latest").file()
 df = pd.read_csv(local_path, index_col='id')
# Out:
# wandb: Currently logged in as: f4ec123. Use `wandb login --relogin` to force relogin
# wandb version 0.15.2 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.2
# Run data is saved locally in <code>/home/hieu/AI/build-ml-pipeline-for-short-term-rental-prices/src/eda/wandb/run-20230516_101712-2l11ve6y</code>
# Syncing run <strong><a href="https://wandb.ai/f4ec123/nyc_airbnb/runs/2l11ve6y" target="_blank">soft-cosmos-26</a></strong> to <a href="https://wandb.ai/f4ec123/nyc_airbnb" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
df
# Out:
#                                                        name    host_id  \
# id
# 9138664                 Private Lg Room 15 min to Manhattan   47594947
# 31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 8741020   Voted #1 Location Quintessential 1BR W Village...   45854238
# 34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 23203149   Big beautiful bedroom in huge Bushwick apartment     143460
# ...                                                     ...        ...
# 7094539                   Tranquil haven in bubbly Brooklyn    2052211
# 4424261                     Large 1 BR with backyard on UWS    3447311
# 4545882                 Amazing studio/Loft with a backyard   23569951
# 26518547          U2 comfortable double bed sleeps 2 guests     295128
# 33631782               Private Bedroom in Williamsburg Apt!    8569221
#
#              host_name neighbourhood_group    neighbourhood  latitude  \
# id
# ...

# %%
# !pip install -U pandas-profiling[notebook]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 1.5 MB/s eta 0:00:000:00:010:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.9/345.9 kB 9.2 MB/s eta 0:00:000:00:01
# ...
#   Using cached ipywidgets-8.0.6-py3-none-any.whl (138 kB)
# ...
#   Using cached widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
# ...
#   Using cached jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 14.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 16.5 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 15.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached pydantic-1.10.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 10.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Create a profile with pandas_profiling

# %%
import pandas_profiling

profile = pandas_profiling.ProfileReport(df)
profile.to_widgets()
# Out:
# /tmp/ipykernel_8749/2516835558.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## Remove outliers

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df
# Out:
#                                                        name    host_id  \
# id
# 9138664                 Private Lg Room 15 min to Manhattan   47594947
# 31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 8741020   Voted #1 Location Quintessential 1BR W Village...   45854238
# 34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 23203149   Big beautiful bedroom in huge Bushwick apartment     143460
# ...                                                     ...        ...
# 7094539                   Tranquil haven in bubbly Brooklyn    2052211
# 4424261                     Large 1 BR with backyard on UWS    3447311
# 4545882                 Amazing studio/Loft with a backyard   23569951
# 26518547          U2 comfortable double bed sleeps 2 guests     295128
# 33631782               Private Bedroom in Williamsburg Apt!    8569221
#
#              host_name neighbourhood_group    neighbourhood  latitude  \
# id
# ...

# %% [markdown]
# ## Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19001 entries, 9138664 to 33631782
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            18994 non-null  object
#  1   host_id                         19001 non-null  int64
#  2   host_name                       18993 non-null  object
#  3   neighbourhood_group             19001 non-null  object
#  4   neighbourhood                   19001 non-null  object
#  5   latitude                        19001 non-null  float64
#  6   longitude                       19001 non-null  float64
#  7   room_type                       19001 non-null  object
#  8   price                           19001 non-null  int64
#  9   minimum_nights                  19001 non-null  int64
#  10  number_of_reviews               19001 non-null  int64
#  11  last_review                     15243 non-null  datetime64[ns]
# ...

# %% [markdown]
# From the results, we have some comments:
# * The number of data rows decreased from 20000 to 19001.
# * The last_review column has been converted to datetime format.

# %% [markdown]
# ## Terminate the run

# %%
run.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# ...
# W&B sync reduced upload amount by 14.9%
# Synced <strong style="color:#cdcd00">fallen-sun-3</strong>: <a href="https://wandb.ai/f4ec123/nyc_airbnb/runs/omyxbxxt" target="_blank">https://wandb.ai/f4ec123/nyc_airbnb/runs/omyxbxxt</a><br/>Synced 7 W&B file(s), 0 media file(s), 4 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20230515_172254-omyxbxxt/logs</code>
